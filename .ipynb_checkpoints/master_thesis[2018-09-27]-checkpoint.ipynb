# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import subprocess

from opmap.RawCam import RawCam
from opmap.VmemMap import VmemMap
from opmap.PhaseMap import PhaseMap
from opmap.PhaseVarianceMap import PhaseVarianceMap
from opmap.util import makeMovie
import cv2

plt.rcParams['font.family'] = 'Times New Roman' #全体のフォントを設定

# %matplotlib inline

# %% [markdown]
# ## 恒温の確認

# %%
data1 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp1/S001/dat00001.csv')
data2 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp1/S003/dat00001.csv')

# %%
np.average(data1['Chan 101 (C)'])
# Out:
# 36.649652

# %%
np.std(data1['Chan 101 (C)'])
# Out:
# 0.21976569089828302

# %%
np.average(data2['Chan 101 (C)'])
# Out:
# 36.55948600000001

# %%
np.std(data2['Chan 101 (C)'])
# Out:
# 0.22450143385733598

# %%
x = data1['Sweep #']
y = data1['Chan 101 (C)']

plt.plot(x*16/1000, y)

plt.xlim([0, 8])
plt.ylim([35, 38])

plt.xticks(size=14)
plt.yticks(size=14)

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.tight_layout()
# plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/Exp1/data1.png', dpi=600, transparent=True)
# plt.close()

# %%
x = data2['Sweep #']
y = data2['Chan 101 (C)']

plt.plot(x*16/1000, y)

plt.xlim([0, 8])
plt.ylim([35, 38])

plt.xticks(size=14)
plt.yticks(size=14)

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.tight_layout()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/Exp1/data2.png', dpi=600, transparent=True)
plt.close()

# %% [markdown]
# ## 冷却開始タイミングの確認

# %%
raw = RawCam(path='/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp4/cam/C001H001S0008/', cam_type='sa4', image_width=512, image_height=512, frame_start=0, frame_end=-1)

# %%
raw.showFrame(330)

# %% [markdown]
# ## 局所冷却ができているか

# %%
data1 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp4/S009/dat00001.csv')
data2 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp4/S008/dat00001.csv')

# %%
x = data1['Sweep #']
y1 = data1['Chan 101 (C)']
y2 = data2['Chan 101 (C)']

# %%
y1_new = y1[258:] - np.average(y1[:258])
y2_new = y2[245:] - np.average(y2[:245])

x1 = np.arange(0.0, len(y1_new))*16/1000
x2 = np.arange(0.0, len(y2_new))*16/1000

plt.plot(x1, y1_new, color='#ff7f00', label='point1')
plt.plot(x2, y2_new, color='green', label='point2')

plt.legend(fontsize=14)

plt.xlim([0, np.max(x1)])
plt.ylim([-9, 1])

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.xticks(size=14)
plt.yticks([-9, -6, -3, 0], size=14)

plt.tight_layout()
# plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/realize_cooling.png', dpi=600, transparent=True)
# plt.close()

# %%
a = pd.rolling_mean(y1_new, 10, 1)
plt.plot(a)
# Out:
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## 冷却温度の差

# %%
data1 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp2/S001/dat00001.csv')
data2 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp3/S001/dat00001.csv')
data3 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S009/dat00001.csv')

# %%
x = data1['Sweep #']
y1 = data1['Chan 101 (C)']
y2 = data2['Chan 101 (C)']
y3 = data3['Chan 101 (C)']

# %%
y1_new = y1[260:] - np.average(y1[:260])
y2_new = y2[225:] - np.average(y2[:225])
y3_new = y3[258:] - np.average(y3[:258])

x1 = np.arange(0.0, len(y1_new))*16/1000
x2 = np.arange(0.0, len(y2_new))*16/1000
x3 = np.arange(0.0, len(y3_new))*16/1000

plt.plot(x1, pd.rolling_mean(y1_new, 10, 1), label='15    ')
plt.plot(x2, pd.rolling_mean(y2_new, 10, 1), label=' 5    ')
plt.plot(x3, pd.rolling_mean(y3_new, 10, 1), label='-5    ')

plt.legend(fontsize=14)

plt.xlim([0, 1.5])
plt.ylim([-5, 1])

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.xticks(size=14)
plt.yticks([-5, -4, -3, -2, -1, 0, 1], size=14)

plt.tight_layout()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/fluid_temperature.png', dpi=600, transparent=True)
plt.close()
# Out:
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:9: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   if __name__ == '__main__':
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:10: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   # Remove the CWD from sys.path while we load stuff.
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# ## 流速による影響

# %% [markdown]
# ### -5℃のとき

# %%
data1 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S009/dat00001.csv')
data2 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S002/dat00001.csv')
data3 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S003/dat00001.csv')
data4 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S004/dat00001.csv')
data5 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S005/dat00001.csv')

# %%
x = data1['Sweep #']
y1 = data1['Chan 101 (C)']
y2 = data2['Chan 101 (C)']
y3 = data3['Chan 101 (C)']
y4 = data4['Chan 101 (C)']
y5 = data5['Chan 101 (C)']

# %%
y1_new = y1[258:] - np.average(y1[:258])
y2_new = y2[248:] - np.average(y2[:248])
y3_new = y3[242:] - np.average(y3[:242])
y4_new = y4[230:] - np.average(y4[:230])
y5_new = y5[239:] - np.average(y5[:239])


x1 = np.arange(0.0, len(y1_new))*16/1000
x2 = np.arange(0.0, len(y2_new))*16/1000
x3 = np.arange(0.0, len(y3_new))*16/1000
x4 = np.arange(0.0, len(y4_new))*16/1000
x5 = np.arange(0.0, len(y5_new))*16/1000


plt.plot(x1, pd.rolling_mean(y1_new, 10, 1), label='point1')
plt.plot(x2, pd.rolling_mean(y2_new, 10, 1), label='point2')
plt.plot(x3, pd.rolling_mean(y3_new, 10, 1), label='point3')
plt.plot(x4, pd.rolling_mean(y4_new, 10, 1), label='point4')
plt.plot(x5, pd.rolling_mean(y5_new, 10, 1), label='point5')

plt.legend(fontsize=14)

plt.xlim([0, 1.5])
plt.ylim([-5, 1])

plt.xticks(size=14)
plt.yticks(size=14)

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.tight_layout()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/speed_-5.png', dpi=600, transparent=True)
plt.close()
# Out:
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:15: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   from ipykernel import kernelapp as app
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:16: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   app.launch_new_instance()
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:17: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
# ...

# %%
y1_new = y1[258:] - np.average(y1[:258])
y5_new = y5[239:] - np.average(y5[:239])


x1 = np.arange(0.0, len(y1_new))*16/1000
x5 = np.arange(0.0, len(y5_new))*16/1000


plt.plot(x1, pd.rolling_mean(y1_new, 10, 1), label='point1')
plt.plot(x5, pd.rolling_mean(y5_new, 10, 1), label='point5')

plt.legend(fontsize=14)

plt.xlim([0, 1.5])
plt.ylim([-5, 1])

plt.xticks(size=14)
plt.yticks(size=14)

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.tight_layout()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/point1-5.png', dpi=600, transparent=True)
plt.close()
# Out:
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:9: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   if __name__ == '__main__':
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:10: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ### 5℃のとき

# %%
data1 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp3/S001/dat00001.csv')
data2 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp3/S002/dat00001.csv')
data3 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp3/S003/dat00001.csv')
data4 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp3/S004/dat00001.csv')
data5 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp3/S005/dat00001.csv')

# %%
x = data1['Sweep #']
y1 = data1['Chan 101 (C)']
y2 = data2['Chan 101 (C)']
y3 = data3['Chan 101 (C)']
y4 = data4['Chan 101 (C)']
y5 = data5['Chan 101 (C)']

# %%
plt.plot(x*16/1000, y1, label='point1')
plt.plot(x*16/1000, y2, label='point2')
plt.plot(x*16/1000, y3, label='point3')
plt.plot(x*16/1000, y4, label='point4')
plt.plot(x*16/1000, y5, label='point5')


plt.legend(fontsize=14)

plt.xlim([0, 8])
plt.ylim([27, 38])

plt.xticks(size=14)
plt.yticks(size=14)

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.tight_layout()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/speed_5.png', dpi=600, transparent=True)
plt.close()

# %% [markdown]
# ### 15℃のとき

# %%
data1 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp2/S001/dat00001.csv')
data2 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp2/S002/dat00001.csv')
data3 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp2/S003/dat00001.csv')
data4 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp2/S004/dat00001.csv')
data5 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp2/S005/dat00001.csv')

# %%
x = data1['Sweep #']
y1 = data1['Chan 101 (C)']
y2 = data2['Chan 101 (C)']
y3 = data3['Chan 101 (C)']
y4 = data4['Chan 101 (C)']
y5 = data5['Chan 101 (C)']

# %%
plt.plot(x*16/1000, y1, label='point1')
plt.plot(x*16/1000, y2, label='point2')
plt.plot(x*16/1000, y3, label='point3')
plt.plot(x*16/1000, y4, label='point4')
plt.plot(x*16/1000, y5, label='point5')


plt.legend(fontsize=14)

plt.xlim([0, 8])
plt.ylim([27, 38])

plt.xticks(size=14)
plt.yticks(size=14)

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.tight_layout()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/speed_15.png', dpi=600, transparent=True)
plt.close()

# %% [markdown]
# ## 深い点での温度変化

# %%
data1 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180915/Exp2/S001/dat00001.csv')

# %%
x = data1['Sweep #']
y1 = data1['Chan 101 (C)']

# %%
y1_new = y1[210:] - np.average(y1[:210])

x1 = np.arange(0.0, len(y1_new))*16/1000

plt.plot(x1, y1_new)

plt.xlim([0, np.max(x1)])
plt.ylim([-3, 1])

plt.xticks(size=14)
plt.yticks([-3, -2, -1, 0, 1], size=14)

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.tight_layout()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/deep_point.png', dpi=600, transparent=True)
plt.close()

# %% [markdown]
# ## カメラ動画の確認

# %%
raw = RawCam(path='/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp4/cam/C001H001S0009/', cam_type='sa4', image_width=512, image_height=512, frame_start=0, frame_end=-1)

# %%
for i in range(400):
    num = "{0:04d}".format(i+3800)
    num_forsave = "{0:04d}".format(i)
    plt.imshow(raw.data[i], cmap='gray', vmin=np.min(raw.data), vmax=np.max(raw.data))
    plt.xticks([])
    plt.yticks([])
    plt.text(15, 50, '%s (ms)' % num, fontsize=18, color='white')
    plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/Exp4/S009/%s.png' % num_forsave, dpi=300)
    plt.close()

# %%
import subprocess
subprocess.call('ffmpeg -r 30 -y -i "/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/Exp4/S009/%04d.png" \
                 -c:v libx264 -pix_fmt yuv420p -qscale 0 \
                 "/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/Exp4//raw_S009.mp4"', shell=True)
# Out:
# 0

# %% [markdown]
# ## 波形解析のプロセス

# %%
data1 = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/Exp4/S009/dat00001.csv')

# %%
x1 = data1['Sweep #']
y1 = data1['Chan 101 (C)']

# %%
plt.subplot(2, 1, 1)
plt.plot(x1*16/1000, y1)

plt.xlim([0, 8])
plt.ylim([26, 38])

plt.vlines(4.13, 26, 38, "red", linestyles='dashed')

plt.xticks(size=14)
plt.yticks([38, 34, 30, 26], size=14)

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.title('Temperature measurement', size=20)

plt.subplot(2, 1, 2)

processed = y1[258:] - np.average(y1[:258])
x2 = np.arange(0.0, len(processed))*16/1000
plt.plot(x2, processed)

plt.xlim([0, np.max(x2)])
plt.ylim([-9, 0])

plt.xlabel('Time (s)', size=16)
plt.ylabel('Temperature (   )', size=16)

plt.xticks(size=14)
plt.yticks([-9, -6, -3, 0], size=14)

plt.title('During regional cooling', size=20)

plt.tight_layout()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/Exp4/processed_temp.png', dpi=600, transparent=True)
plt.close()

# %%
np.max(x2)
# Out:
# 3.856

# %% [markdown]
# ## 遅い冷却の確認

# %%
vmem1 = RawCam(path='/mnt/recordings/SimulationResults/2D/20180911-1/', cam_type='numpy',
                   image_width=200, image_height=200, frame_start=0, frame_end=-1)
vmem_temp = VmemMap(vmem1)
vmem1.cmap = vmem_temp.cmap

vmem2 = RawCam(path='/mnt/recordings/SimulationResults/2D/20180915-1/', cam_type='numpy',
                   image_width=200, image_height=200, frame_start=0, frame_end=-1)
vmem2.cmap = vmem_temp.cmap

# %%
vmem = np.vstack((vmem1.data, vmem2.data))

# %%
plt.imshow(vmem[100, :, :], cmap=vmem_temp.cmap, vmin=np.min(vmem), vmax=np.max(vmem))
plt.text(5, 10, '%s (ms)' % num, fontsize=24, color='white', horizontalalignment='left', verticalalignment='top')
plt.colorbar()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/simulation/LuoRudy/20180917/20180911-1/vmem_sample.png', dpi=300)
plt.close()

# %%
for i in range(1500):
    num = "{0:04d}".format(i)
    plt.imshow(vmem[i, :, :], cmap=vmem_temp.cmap, vmin=np.min(vmem), vmax=np.max(vmem))
    plt.text(5, 10, '%s (ms)' % num, fontsize=24, color='white', horizontalalignment='left', verticalalignment='top')
    plt.xticks([])
    plt.yticks([])
    plt.savefig('/mnt/recordings/AnalysisResult/Seno/simulation/LuoRudy/20180917/20180911-1/vmem/%s.png' % num, dpi=300)
    plt.close()

# %%
num = "{0:04d}".format(1500)
plt.imshow(vmem[1500, :, :], cmap=vmem_temp.cmap, vmin=np.min(vmem), vmax=np.max(vmem))
plt.text(5, 10, '%s (ms)' % num, fontsize=24, color='white', horizontalalignment='left', verticalalignment='top')
plt.xticks([])
plt.yticks([])
plt.savefig('/mnt/recordings/AnalysisResult/Seno/simulation/LuoRudy/20180917/20180911-1/vmem/1500.png', dpi=300)
plt.close()

# %%
vmem1.data.shape
# Out:
# (944, 200, 200)

# %%
temp_array1 = np.zeros_like(vmem1.data)
temp_array2 = np.zeros_like(vmem2.data)

for i in range(temp_array1.shape[0]):
    num = "{0:04d}".format(i)
    temp_array1[i] = np.load('/mnt/recordings/SimulationResults/2D/20180911-1/cell_%s/temp.npy' % num).reshape((200, 200))
    
for i in range(temp_array2.shape[0]):
    num = "{0:04d}".format(i)
    temp_array2[i] = np.load('/mnt/recordings/SimulationResults/2D/20180915-1/cell_%s/temp.npy' % num).reshape((200, 200))

# %%
temp = np.vstack((temp_array1, temp_array2))

# %%
plt.imshow(temp[i, :, :], cmap='jet', vmin=np.min(temp), vmax=np.max(temp))
plt.colorbar()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/simulation/LuoRudy/20180917/20180911-1/temp_sample.png')
plt.close()

# %%
for i in range(1500):
    num = "{0:04d}".format(i)
    plt.imshow(temp[i, :, :], cmap='jet', vmin=np.min(temp), vmax=np.max(temp))
    plt.text(5, 10, '%s (ms)' % num, fontsize=24, color='white', horizontalalignment='left', verticalalignment='top')
    plt.xticks([])
    plt.yticks([])
    plt.savefig('/mnt/recordings/AnalysisResult/Seno/simulation/LuoRudy/20180917/20180911-1/temp/%s.png' % num, dpi=300)
    plt.close()

# %%
num = "{0:04d}".format(1500)
plt.imshow(temp[1500, :, :], cmap='jet', vmin=np.min(temp), vmax=np.max(temp))
plt.text(5, 10, '%s (ms)' % num, fontsize=24, color='white', horizontalalignment='left', verticalalignment='top')
plt.xticks([])
plt.yticks([])
plt.savefig('/mnt/recordings/AnalysisResult/Seno/simulation/LuoRudy/20180917/20180911-1/temp/1500.png', dpi=300)
plt.close()

# %% [markdown]
# ## ヒートマップ作成

# %% [markdown]
# ### 15℃

# %%
heatmap15 = np.zeros((5,2,100))

# %%
data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp2/S001/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[260:] - np.average(y1[:260])
heatmap15[0,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp2/S002/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[262:] - np.average(y1[:262])
heatmap15[1,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp2/S003/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[261:] - np.average(y1[:261])
heatmap15[2,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp2/S004/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[277:] - np.average(y1[:277])
heatmap15[3,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp2/S005/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[230:] - np.average(y1[:230])
heatmap15[4,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp2/S006/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[247:] - np.average(y1[:247])
heatmap15[0,1] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp2/S007/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[247:] - np.average(y1[:247])
heatmap15[2,1] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp2/S008/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[257:] - np.average(y1[:257])
heatmap15[4,1] = pd.rolling_mean(y1_new, 10, 1)[:100]

heatmap15[1,1] = np.NaN
heatmap15[3,1] = np.NaN
# Out:
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   """
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   # This is added back by InteractiveShellApp.init_path()
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:17: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
# ...

# %% [markdown]
# ### 5℃

# %%
heatmap5 = np.zeros((5,2,100))

# %%
data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp3/S001/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[225:] - np.average(y1[:225])
heatmap5[0,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp3/S002/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[250:] - np.average(y1[:250])
heatmap5[1,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp3/S003/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[242:] - np.average(y1[:242])
heatmap5[2,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp3/S004/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[243:] - np.average(y1[:243])
heatmap5[3,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp3/S005/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[235:] - np.average(y1[:235])
heatmap5[4,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp3/S006/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[248:] - np.average(y1[:248])
heatmap5[0,1] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp3/S007/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[236:] - np.average(y1[:236])
heatmap5[2,1] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp3/S008/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[236:] - np.average(y1[:236])
heatmap5[4,1] = pd.rolling_mean(y1_new, 10, 1)[:100]

heatmap5[1,1] = np.NaN
heatmap5[3,1] = np.NaN
# Out:
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   """
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   # This is added back by InteractiveShellApp.init_path()
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:17: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
# ...

# %% [markdown]
# ### - 5℃

# %%
heatmapminus5 = np.zeros((5,2,100))

# %%
data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S009/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[258:] - np.average(y1[:258])
heatmapminus5[0,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S002/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[249:] - np.average(y1[:249])
heatmapminus5[1,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S003/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[243:] - np.average(y1[:243])
heatmapminus5[2,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S004/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[230:] - np.average(y1[:230])
heatmapminus5[3,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S005/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[239:] - np.average(y1[:239])
heatmapminus5[4,0] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S006/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[229:] - np.average(y1[:229])
heatmapminus5[0,1] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S007/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[229:] - np.average(y1[:229])
heatmapminus5[2,1] = pd.rolling_mean(y1_new, 10, 1)[:100]

data = pd.read_csv('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/data/20180912/Exp4/S008/dat00001.csv')
x = data['Sweep #']
y1 = data['Chan 101 (C)']
y1_new = y1[246:] - np.average(y1[:246])
heatmapminus5[4,1] = pd.rolling_mean(y1_new, 10, 1)[:100]

heatmapminus5[1,1] = np.NaN

heatmapminus5[3,1] = np.NaN
# Out:
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   """
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
#   # This is added back by InteractiveShellApp.init_path()
# /home/tomii/.pyenv/versions/anaconda2-4.4.0/lib/python2.7/site-packages/ipykernel_launcher.py:17: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(min_periods=1,window=10,center=False).mean()
# ...

# %%
for i in range(1600):
    num = "{0:04d}".format(i)
    
    plt.figure(figsize=(4,4))
    
    plt.subplot(1,3,1)
    plt.imshow(heatmap15[:, :, i//16], vmax=0, vmin=-5)
    plt.xticks([])
    plt.yticks([])
    plt.text(0, -1, '15    ', fontsize=18, color='black', horizontalalignment='left', verticalalignment='top')
    plt.tight_layout()

    plt.subplot(1,3,2)
    plt.imshow(heatmap5[:, :, i//16], vmax=0, vmin=-5)
    plt.xticks([])
    plt.yticks([])
    plt.text(0, -1, ' 5    ', fontsize=18, color='black', horizontalalignment='left', verticalalignment='top')
    plt.text(-0.65, -1.8, '%s (ms)' % num, fontsize=24, color='black', horizontalalignment='left', verticalalignment='top')
    plt.tight_layout()


    plt.subplot(1,3,3)
    plt.imshow(heatmapminus5[:, :, i//16], vmax=0, vmin=-5)
    plt.xticks([])
    plt.yticks([])
    plt.text(0, -1, '- 5    ', fontsize=18, color='black', horizontalalignment='left', verticalalignment='top')
    plt.tight_layout()
    
    plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/heatmaps/%s.png' % num, dpi=300)
    plt.close()

# %%
import subprocess
subprocess.call('ffmpeg -r 60 -y -i "/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/heatmaps/%04d.png" \
                 -c:v libx264 -pix_fmt yuv420p -qscale 0 \
                 "/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/heatmap.mp4"', shell=True)
# Out:
# 0

# %%
plt.imshow(heatmapminus5[:, :, i//16], vmax=0, vmin=-5)
plt.colorbar()
plt.savefig('/mnt/recordings/AnalysisResult/Seno/experiment/20180912/analysis/heatmap_sample.png', dpi=300)
